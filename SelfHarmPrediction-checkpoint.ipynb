# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#import python classes and packages
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor #extension decision tree

# %%
#read and display dataset values
dataset = pd.read_csv("Dataset/selfharm_and_mental_signals_time_series_data.csv")
dataset.fillna(0, inplace = True)#remove missing values
dataset.head()
# Out:
#          date    MS-Pos    MS-Neg    MS-Amb    MS-Neu    ME-Ang    ME-Dis  \
# 0  2017-10-31  0.124349  0.217099  0.002639  0.655914  0.060558  0.001121
# 1  2017-11-30  0.122213  0.199027  0.002266  0.676494  0.041806  0.001326
# 2  2017-12-31  0.103728  0.244845  0.002444  0.648983  0.057183  0.001756
# 3  2018-01-31  0.096537  0.269589  0.002332  0.631543  0.055182  0.001676
# 4  2018-02-28  0.093888  0.288119  0.001998  0.615995  0.063627  0.001289
#
#      ME-Fea    ME-Joy    ME-Sad    ME-Sur    ME-Neu     M-NST      M-ST  \
# 0  0.010423  0.180025  0.042351  0.098291  0.607230  0.734283  0.265717
# 1  0.016026  0.182476  0.033406  0.104943  0.620016  0.753447  0.246553
# 2  0.011395  0.179296  0.040314  0.113988  0.596068  0.743003  0.256997
# 3  0.012206  0.152939  0.024959  0.116959  0.636079  0.746279  0.253721
# 4  0.011892  0.163508  0.035321  0.118380  0.605983  0.728080  0.271920
#
#    GH-Death  GH-Injure
# 0      56.0      224.0
# 1      45.0      239.0
# 2      60.0      255.0
# 3      88.0      336.0
# 4      60.0      299.0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       42 non-null     object
#  1   MS-Pos     42 non-null     float64
#  2   MS-Neg     42 non-null     float64
#  3   MS-Amb     42 non-null     float64
#  4   MS-Neu     42 non-null     float64
#  5   ME-Ang     42 non-null     float64
#  6   ME-Dis     42 non-null     float64
#  7   ME-Fea     42 non-null     float64
#  8   ME-Joy     42 non-null     float64
#  9   ME-Sad     42 non-null     float64
#  10  ME-Sur     42 non-null     float64
#  11  ME-Neu     42 non-null     float64
#  12  M-NST      42 non-null     float64
#  13  M-ST       42 non-null     float64
#  14  GH-Death   42 non-null     float64
#  15  GH-Injure  42 non-null     float64
# dtypes: float64(15), object(1)
# memory usage: 5.4+ KB

# %%
#extract training features and label from dataset
dataset = dataset.values
X = dataset[:,1:dataset.shape[1]-2] #xtract training features
injury = dataset[:,dataset.shape[1]-2] #get injury values from dataset
death = dataset[:,dataset.shape[1]-1] #get death values
#perform shuffling as data preprocessing
indices = np.arange(X.shape[0])
np.random.shuffle(indices)
X = X[indices]
injury = injury[indices]
death = death[indices]
print("Processed Training Features : "+str(X))
# Out:
# Processed Training Features : [[0.099156265253469 0.2724443902098877 0.0046283383306603
#   0.6237710062059828 0.0546335680914859 0.0016996722683215
#   0.0100847221253748 0.1577644515724147 0.0265584687260302
#   0.101919322222997 0.6473397949933757 0.7482654626595077
#   0.2517345373404923]
#  [0.1986672645881029 0.259466433792002 0.0016285491751044
#   0.5402377524447907 0.0337353568253518 0.0002360216195803
#   0.0067580857073174 0.2463042948067377 0.0185512992990157
#   0.1041642081081293 0.5902507336338675 0.4948271928375306
#   0.5051728071624694]
#  [0.115433070094168 0.2674696196512693 0.0032353416962014
#   0.6138619685583612 0.0490105246645784 0.0014951200262748
#   0.0170688784638989 0.203071613798242 0.0385152722834159
#   0.7168087996988198 0.0411994827557985 0.0002618957982092
#   0.0120308382302391 0.1160853125562666 0.0195930794035323
#   0.1153323621364149 0.6954970291195389 0.3924835905913934
#   0.6075164094086065]
#  [0.1098808481102609 0.2499876055593198 0.0033217101022954
#   0.6368098362281238 0.0584687081687627 0.001702169853415
#   0.0106592189849779 0.1660689791938655 0.0244583629422749
#   0.109847796268447 0.6287947645882567 0.7428401447670672
#   0.2571598552329328]
#  [0.2433868320769937 0.2662049270766691 0.0009179160524046
#   0.4894903247939325 0.0309124456436075 0.0001668938277099
#   0.0070837157983551 0.2742992777206012 0.021826003912733
#   0.0869238685989263 0.5787877944980668 0.4756195933353731
#   0.5243804066646268]]

# %%
#split dataset into train and test
injury_X_train, injury_X_test, injury_y_train, injury_y_test = train_test_split(X, injury, test_size=0.2)
death_X_train, death_X_test, death_y_train, death_y_test = train_test_split(X, death, test_size=0.2)
print("Dataset Train & Test Splits")
print("Total records found in dataset : "+str(X.shape[0]))
print("80% dataset used for training  : "+str(injury_X_train.shape[0]))
print("20% dataset user for testing   : "+str(injury_X_test.shape[0]))
# Out:
# Dataset Train & Test Splits
# Total records found in dataset : 42
# 80% dataset used for training  : 33
# 20% dataset user for testing   : 9

# %%
#define global variables to calculate mae, mape and Rmse
rmse = []
mae = []
mape = []

# %%
#function to calculate RMSE and other metrics
def calculateMetrics(algorithm, predict, test_labels, info):
    mape_value = mean_squared_error(test_labels, predict)
    rmse_value = sqrt(mape_value)
    mae_value= mean_absolute_error(test_labels, predict)
    predict = predict.ravel()
    test_label = test_labels.ravel()
    mae.append(mae_value)
    rmse.append(rmse_value)
    mape.append(mape_value)
    print(algorithm+" "+info+" MAPE      : "+str(mape_value))
    print(algorithm+" "+info+" RMSE     : "+str(rmse_value))
    print(algorithm+" "+info+" MAE : "+str(mae_value)+"\n")    
    for i in range(len(predict)):
        print("True "+info +" : "+str(test_label[i])+" Predicted "+info+" : "+str(predict[i]))
    plt.plot(test_label, color = 'red', label = 'True '+info)
    plt.plot(predict, color = 'green', label = 'Predicted '+info)
    plt.title(algorithm+' '+info+" Prediction")
    plt.xlabel('Test Data')
    plt.ylabel('Predicted '+info)
    plt.legend()
    plt.show()

# %%
#now train Linear XGBoost algorithm on injury data and calculate performnace metrics
xgb = XGBRegressor()
xgb.fit(injury_X_train, injury_y_train)
predict = xgb.predict(injury_X_test)
calculateMetrics("XGBoost", predict, injury_y_test, "Injury")
# Out:
# XGBoost Injury MAPE      : 3427.709502024447
# XGBoost Injury RMSE     : 58.5466438152047
# XGBoost Injury MAE : 41.14164055718316
#
# True Injury : 372.0 Predicted Injury : 375.43222
# True Injury : 154.0 Predicted Injury : 150.84946
# True Injury : 158.0 Predicted Injury : 132.44067
# True Injury : 106.0 Predicted Injury : 87.23977
# True Injury : 60.0 Predicted Injury : 88.35255
# True Injury : 146.0 Predicted Injury : 127.986015
# True Injury : 434.0 Predicted Injury : 315.80554
# True Injury : 56.0 Predicted Injury : 96.386406
# True Injury : 230.0 Predicted Injury : 115.57495

# %%
#now train XGBoost algorithm on death data and calculate performnace metrics
xgb = XGBRegressor()
xgb.fit(death_X_train, death_y_train)
predict = xgb.predict(death_X_test)
calculateMetrics("XGBoost", predict, death_y_test, "Death")
# Out:
# XGBoost Death MAPE      : 12435.704088061324
# XGBoost Death RMSE     : 111.5154881084297
# XGBoost Death MAE : 97.13657972547743
#
# True Death : 444.0 Predicted Death : 293.5313
# True Death : 478.0 Predicted Death : 398.51636
# True Death : 900.0 Predicted Death : 840.0324
# True Death : 550.0 Predicted Death : 613.2768
# True Death : 255.0 Predicted Death : 433.4177
# True Death : 538.0 Predicted Death : 519.4747
# True Death : 407.0 Predicted Death : 569.4653
# True Death : 1147.0 Predicted Death : 1022.9989
# True Death : 935.0 Predicted Death : 972.6231

# %%
#now train random forest algorithm on injury data and calculate performnace metrics
rf = RandomForestRegressor(n_estimators=2, max_depth=30)
rf.fit(injury_X_train, injury_y_train)
predict = rf.predict(injury_X_test)
calculateMetrics("Random Forest", predict, injury_y_test, "Injury")
# Out:
# Random Forest Injury MAPE      : 6656.416666666667
# Random Forest Injury RMSE     : 81.58686577303155
# Random Forest Injury MAE : 63.611111111111114
#
# True Injury : 372.0 Predicted Injury : 360.5
# True Injury : 154.0 Predicted Injury : 127.0
# True Injury : 158.0 Predicted Injury : 127.0
# True Injury : 106.0 Predicted Injury : 85.0
# True Injury : 60.0 Predicted Injury : 195.5
# True Injury : 146.0 Predicted Injury : 71.5
# True Injury : 434.0 Predicted Injury : 331.0
# True Injury : 56.0 Predicted Injury : 74.0
# True Injury : 230.0 Predicted Injury : 79.0

# %%
#now train Random Forest algorithm on death data and calculate performnace metrics
rf = RandomForestRegressor(n_estimators=2, max_depth=20)
rf.fit(death_X_train, death_y_train)
predict = rf.predict(death_X_test)
calculateMetrics("Random Forest", predict, death_y_test, "Death")
# Out:
# Random Forest Death MAPE      : 10180.138888888889
# Random Forest Death RMSE     : 100.89667432026137
# Random Forest Death MAE : 73.05555555555556
#
# True Death : 444.0 Predicted Death : 327.5
# True Death : 478.0 Predicted Death : 459.5
# True Death : 900.0 Predicted Death : 843.0
# True Death : 550.0 Predicted Death : 554.0
# True Death : 255.0 Predicted Death : 463.0
# True Death : 538.0 Predicted Death : 553.5
# True Death : 407.0 Predicted Death : 468.0
# True Death : 1147.0 Predicted Death : 982.5
# True Death : 935.0 Predicted Death : 922.5

# %%
#now train decision tree as extension model on injury data
dt_rg = DecisionTreeRegressor()
dt_rg.fit(X[0:35], injury[0:35])
predict = dt_rg.predict(injury_X_test)
calculateMetrics("Extension Decision Tree", predict, injury_y_test, "Injury")
# Out:
# Extension Decision Tree Injury MAPE      : 25.0
# Extension Decision Tree Injury RMSE     : 5.0
# Extension Decision Tree Injury MAE : 1.6666666666666667
#
# True Injury : 372.0 Predicted Injury : 372.0
# True Injury : 154.0 Predicted Injury : 154.0
# True Injury : 158.0 Predicted Injury : 158.0
# True Injury : 106.0 Predicted Injury : 91.0
# True Injury : 60.0 Predicted Injury : 60.0
# True Injury : 146.0 Predicted Injury : 146.0
# True Injury : 434.0 Predicted Injury : 434.0
# True Injury : 56.0 Predicted Injury : 56.0
# True Injury : 230.0 Predicted Injury : 230.0

# %%
#now train decision tree algorithm as extension on death data and calculate performnace metrics
dt_death = DecisionTreeRegressor()
dt_death.fit(X[0:36], death[0:36])
predict = dt_death.predict(death_X_test)
calculateMetrics("Extension Decision Tree", predict, death_y_test, "Death")
# Out:
# Extension Decision Tree Death MAPE      : 5930.0
# Extension Decision Tree Death RMSE     : 77.00649323271382
# Extension Decision Tree Death MAE : 26.0
#
# True Death : 444.0 Predicted Death : 444.0
# True Death : 478.0 Predicted Death : 478.0
# True Death : 900.0 Predicted Death : 900.0
# True Death : 550.0 Predicted Death : 319.0
# True Death : 255.0 Predicted Death : 255.0
# True Death : 538.0 Predicted Death : 535.0
# True Death : 407.0 Predicted Death : 407.0
# True Death : 1147.0 Predicted Death : 1147.0
# True Death : 935.0 Predicted Death : 935.0

# %%
#display all algorithms performance on injury data
columns = ["Prediction Type", "Algorithm Name","MAE","RMSE","MAPE"]
values = []
algorithm_names = ["XGBoost", "Random Forest", "Extension Decision Tree"]
i = 0
names = 0
while i < len(mae):
    values.append(["Injury", algorithm_names[names],mae[i],rmse[i],mape[i]])
    i = i + 2
    names = names + 1
injury_df = pd.DataFrame(values,columns=columns)
injury_df
# Out:
#   Prediction Type           Algorithm Name        MAE       RMSE         MAPE
# 0          Injury                  XGBoost  41.141641  58.546644  3427.709502
# 1          Injury            Random Forest  63.611111  81.586866  6656.416667
# 2          Injury  Extension Decision Tree   1.666667   5.000000    25.000000

# %%
#display all algorithms performance on death data
columns = ["Prediction Type", "Algorithm Name","MAE","RMSE","MAPE"]
values = []
algorithm_names = ["XGBoost", "Random Forest", "Extension Decision Tree"]
i = 1
names = 0
while i < len(mae):
    values.append(["Death", algorithm_names[names],mae[i],rmse[i],mape[i]])
    i = i + 2
    names = names + 1
death_df = pd.DataFrame(values,columns=columns)
death_df
# Out:
#   Prediction Type           Algorithm Name        MAE        RMSE  \
# 0           Death                  XGBoost  97.136580  111.515488
# 1           Death            Random Forest  73.055556  100.896674
# 2           Death  Extension Decision Tree  26.000000   77.006493
#
#            MAPE
# 0  12435.704088
# 1  10180.138889
# 2   5930.000000

# %%
import joblib
joblib.dump(dt_rg,'model.sav')
# Out:
# ['model.sav']

# %%
joblib.dump(dt_death,'model1.sav')
# Out:
# ['model1.sav']

# %%
import matplotlib.pyplot as plt

# Injury Graph
plt.figure()
injury_df.set_index("Algorithm Name")[["MAE", "RMSE", "MAPE"]].plot(kind="bar")
plt.title("Algorithm Performance on Injury Data")
plt.xlabel("Algorithm")
plt.ylabel("Error Values")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# Death Graph
plt.figure()
death_df.set_index("Algorithm Name")[["MAE", "RMSE", "MAPE"]].plot(kind="bar")
plt.title("Algorithm Performance on Death Data")
plt.xlabel("Algorithm")
plt.ylabel("Error Values")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
plt.figure()
injury_df.set_index("Algorithm Name")[["MAE", "RMSE", "MAPE"]].plot(kind="bar")
plt.yscale("log")
plt.title("Algorithm Performance on Injury Data (Log Scale)")
plt.show()

# %%
metrics = ["MAE", "RMSE", "MAPE"]

for metric in metrics:
    plt.figure()
    plt.bar(injury_df["Algorithm Name"], injury_df[metric])
    plt.title(f"Injury - {metric}")
    plt.xticks(rotation=0)
    plt.show()

# %%
#perform prediction of injury on test data using extension model
#read test data and predict flood
dataset = pd.read_csv("Dataset/testData.csv")
dataset.fillna(0, inplace = True)
dataset = dataset.values
X = dataset[:,1:dataset.shape[1]]
injury_predict = dt_rg.predict(X) #perform injury prediction using extension decision tree object
death_predict = dt_death.predict(X)#perform death prediction using extension decision tree object
for i in range(len(injury_predict)):
    print("Test Data = "+str(dataset[i])+"=====> Forecasted Injury : "+str(injury_predict[i])+" Forecasted Death : "+str(death_predict[i])+"\n\n")
# Out:
# Test Data = ['2019-04-30' 0.1001397518460463 0.2199769598307869 0.005684500764858
#  0.6741987875583086 0.0387622518932598 0.0016052576910728
#  0.0078279919170553 0.143812203735529 0.0192914203697758
#  0.0881664180091027 0.7005344563842043 0.7598156786462956
#  0.2401843213537044]=====> Forecasted Injury : 146.0 Forecasted Death : 319.0
#
#
# Test Data = ['2019-05-31' 0.1055472075148101 0.2527987790007002 0.0055070844708085
#  0.6361469290136812 0.04802964384898 0.001667859868302 0.0095823269792068
#  0.1715928848468637 0.0302102919541495 0.099568087232218
#  0.6393489052702799 0.7391766121989788 0.2608233878010212]=====> Forecasted Injury : 158.0 Forecasted Death : 535.0
#
#
# Test Data = ['2019-06-30' 0.1045612288819541 0.2629936511352631 0.0056628645216829
#  0.6267822554610998 0.0522099967717636 0.0013181964919832
#  0.0121462391047024 0.1625955019907457 0.0389809534057893
#  0.097963520929732 0.6347855913052836 0.7278462283439148
#  0.2721537716560852]=====> Forecasted Injury : 154.0 Forecasted Death : 514.0
#
#
# Test Data = ['2019-07-31' 0.0964788732394366 0.2466329225352113 0.0038952464788732
#  0.6529929577464789 0.0439810739436619 0.0015184859154929
#  0.0089458626760563 0.1723041373239436 0.0295224471830985
#  0.0943992077464788 0.6493287852112676 0.7587918133802817
#  0.2412081866197183]=====> Forecasted Injury : 113.0 Forecasted Death : 407.0
#
#
# Test Data = ['2019-08-31' 0.1086958335767154 0.2573035489281453 0.0039302731164312
#  0.6300703443787081 0.0471799664549937 0.001560426906099
#  0.0121579786213169 0.1877352114086399 0.031917823079298 0.103054932033812
#  0.6163936614958403 0.7587930473385125 0.2412069526614875]=====> Forecasted Injury : 154.0 Forecasted Death : 478.0
#
#
# Test Data = ['2019-09-30' 0.115433070094168 0.2674696196512693 0.0032353416962014
#  0.6138619685583612 0.0490105246645784 0.0014951200262748
#  0.0170688784638989 0.203071613798242 0.0385152722834159
#  0.1003102986808629 0.5905282920827267 0.7461531297028878
#  0.2538468702971122]=====> Forecasted Injury : 146.0 Forecasted Death : 537.0

# %%
x = pd.DataFrame(injury_X_train)

# %%
x
# Out:
#           0         1         2         3         4         5         6   \
# 0   0